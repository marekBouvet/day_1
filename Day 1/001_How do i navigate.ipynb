# %% [markdown]
# ## If you prefer using the mouse cursor instead of keyboard
#
# ![image.png](attachment:8a3687ea-974b-4115-acb9-96c02b098164.png)

# %% [markdown]
# # Keyboard

# %% [markdown]
# ## We use the key arrows to navigate Up and Down
#
# ![image.png](attachment:420a8189-6aa5-4b23-94f7-a2fca5b4a9ac.png)

# %% [markdown]
# ## Shift + Enter to run a code cell
#
# ![image.png](attachment:a3762830-3e8b-46a4-ad80-32924a103f80.png)

# %% [markdown]
# ## Esc to leave a cell (command mode)
#
# ![image.png](attachment:979ca403-3d03-4cb1-b668-c469a54e47ba.png)

# %% [markdown]
# ## Enter to go into a cell (Edit mode)
#
# ![image.png](attachment:ec209ac7-ecd0-4259-8f7e-e4da439d1a1b.png)

# %% [markdown]
# ## Cmd + shift + H opens the keyboard shortcut list

# %% [markdown]
# # Command mode

# %% [markdown]
# ## In Command mode press B or A to create a cell Below or Above respectively

# %% [markdown]
# ## Press D twice, i.e. DD, to delete a cell

# %% [markdown]
# ## Press Z if you regret the last action

# %% [markdown]
# ## Press M to turn a cell into a text cell, like this one

# %% [markdown]
# ## Press Y to turn it back into a code cell, like the one below

# %%
## Press Y to turn it back into a code cell

# %% [markdown]
# # Edit mode

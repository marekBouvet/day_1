# %% [markdown]
# # Why Python
#
# - Easy to learn
# - Many practitioners
# - Very generalist
# - Python can do nearly everything other programming languages can do, just not as good

# %% [markdown]
# ![image.png](attachment:0d7abca5-a872-428f-adea-c9a90d39fa93.png)

# %% [markdown]
# ## Different ways to use Python
#
# - Jupyter notebooks
# - Command-line or terminal & text editor
#     - Writing python script
#     - Runnning the .py file
# - Integrated Development Environments
#     - PyCharm
#     - VSCode

# %% [markdown]
# ## Build companies Using the Web Framework Django
#
# ![Sites built using Django](attachment:08363402-6889-4c8e-9e9e-f223d3a78a8b.png)

# %% [markdown]
# ## Machine Learning

# %%
# %run 'plot_adaboost_regression.py'

# %% [markdown]
# - Run RL project

# %% [markdown]
# ## Automate & Load and Process Data

# %%
# !python -m process_energy_consumption_files sample_data

# %% [markdown]
# ## Create Apps & Artificial Intelligence
#
# - QnA-bot

# %% [markdown]
# # What is programming

# %% [markdown]
# ## Programming is to instruct a computer to solve a problem
# ![image.jpeg](attachment:8287e8ef-174f-4d0a-a5a7-de93dbe3376f.jpeg)

# %% [markdown]
# if I    make mitsake at this seNtenCe,
#
# 					 you stil unedrstand Me.!
# ![image.png](attachment:2f9d52a9-9628-4510-ad06-a6a3a8c00582.png)

# %% [markdown]
# ## Hey, wanna grab a coffee at my place tomorrow around 3 o’clock?
# ![image.png](attachment:45033739-cea2-4540-93d0-237e798dcbc4.png)

# %% [markdown]
# # Schedule

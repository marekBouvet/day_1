# %% [markdown]
# # Download Python

# %% [markdown]
# Preferably via [Anaconda](https://www.anaconda.com/download)

# %% [markdown]
# # Start Jupyter Lab
#
# Jupyter lab works best on:
#
# - Chrome
# - Firefox
# - Safari
#
# If you use another webbrowser as default you can "move" jupyter lab over to another browser by copy/pasting the URL of the webpage where you have jupyter lab open. It should look something like this:
#
# > http://localhost:8889/lab/tree/

# %% [markdown]
# ![start jupyter lab](attachment:image.png)

# %% [markdown]
# # Create new environment

# %% [markdown]
# ![Create a new environment](attachment:image.png)

# %% [markdown]
# # Install packages

# %% [markdown]
# ![install packages](attachment:image.png)

# %% [markdown]
# ![Install package](attachment:image.png)
